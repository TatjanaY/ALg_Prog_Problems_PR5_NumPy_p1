# %% [markdown]
# # Введение в NumPy. Возможности библиотеки NumPy для работы с массивами. Массивы случайных чисел

# %% [markdown]
# # Вариант 35

# %% [markdown]
# ## Задача 1. Одномерный массив numpy

# %% [markdown]
# Создайте одномерный массив чисел от 10 до 18.
#
# Сделайте это двумя способами:

# %% [markdown]
# **Вывод**
#
# ```
# array([10, 11, 12, 13, 14, 15, 16, 17, 18])
# ```

# %% [markdown]
# - с помощью `arange`

# %%
# ваш код тут

# %% [markdown]
# - с помощью преобразования списка (list) в numpy `array`

# %%
# ваш код тут

# %% [markdown]
# ## Задача 2

# %% [markdown]
# Создайте массив numpy размером 5×5, заполненный значениями `False`.
# Установите значения `True` для всех элементов в четных строках (0, 2, 4).
#
# *Подсказка:* создайте массив из нулей, приведите тип к `bool` и используйте срезы.

# %% [markdown]
# **Вывод**
#
# ```
# array([[ True,  True,  True,  True,  True],
#        [False, False, False, False, False],
#        [ True,  True,  True,  True,  True],
#        [False, False, False, False, False],
#        [ True,  True,  True,  True,  True]])
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 3

# %% [markdown]
# Создайте массив 4*4, заполненный случайными целыми числами в интервале от 10 до 50.
# Выведите на экран:
#
# 1.   Массив
# 2.   Элемент на пересечении первой строки первого столбца
# 3.   Элемент на пересечении второй строки третьего столбца
# 4.   Элемент на пересечении четвертой строки второго столбца
# 5.   Последний элемент массива

# %% [markdown]
# **Вывод (случайный массив)**
#
# ```
# [[23 45 12 38]
#  [15 29 41 19]
#  [33 10 27 49]
#  [11 36 14 22]]
# 23
# 41
# 36
# 22
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 4

# %% [markdown]
# Вам дан массив под названием `test_array`. Выведите отрицательные элементы этого массива.

# %%
test_array = np.array([-5, 10, -3, 0, 8, -1, 12, -8, 4, -2])

# %% [markdown]
# **Вывод**
#
# ```
# array([-5, -3, -1, -8, -2])
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 5

# %% [markdown]
# Вам дан массив `arr`. Выведите все его элементы, которые больше или равны 4, и меньше или равны 8.
#
# *Подсказка:* здесь можно использовать булевы маски.

# %%
arr = np.array([3, 6, 9, 4, 7, 2, 8, 5, 1, 10])

# %% [markdown]
# **Вывод**
#
# ```
# array([6, 4, 7, 8, 5])
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 6. Замена элементов массива

# %% [markdown]
# Замените элементы из массива `test_array`, которые больше 10, на значение `10`.
#
# *Подсказка:* вам пригодится функция `np.where`.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# test_array = np.array([12, 3, 5, 15, 2, 8, 20, 1, 9, 11])
# ```
#
# **Вывод:**
#
# ```
# array([10,  3,  5, 10,  2,  8, 10,  1,  9, 10])
# ```

# %%
# ваш код в этой ячейке

# %% [markdown]
# ## Задача 7. Случайная матрица

# %% [markdown]
# Программа принимает на вход четыре числа `n` - количество строк матрицы, `m` - количество столбцов матрицы, `a1` - начало интервала для заполнения матрицы случайными числами, `a2` - конец интервала для заполнения матрицы случайными числами.
#
# Создайте массив `n*m`, заполненный случайными целыми числами в интервале от `a1` до `a2`, и выведите его на экран.
# Подсчитайте и выведите на экран количество элементов массива, меньших значения середины интервала от `a1` до `a2`.

# %% [markdown]
# **Вывод (случайный массив)**
#
# ```
# [[97 88 71 63 62]
#  [92 64 50 80 50]
#  [92 64 93 51 57]
#  [78 50 95 66 55]
#  [54 50 96 64 55]]
# Количество элементов массива, меньших значения середины интервала от a1 до a2: 16
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 8. Применим функцию к массиву аргументов

# %% [markdown]
# y = x^2 - 2 sin(x) + 1

# %% [markdown]
# Запрограммируйте функцию с использованием возможностей numpy
#
# `y = x^2 - 2 sin(x) + 1`
#
# Создайте массив 3*3 и примените функцию сразу ко всем его аргументам.
# На экран вывести исходный массив и результат применения функции.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# [[6 4 8]
#  [7 1 8]
#  [3 5 5]]
# ```
#
# **Вывод:**
#
# ```
# [[6 4 8]
#  [7 1 8]
#  [3 5 5]]
# ---------------
# [[3.55705630e+01 1.51436621e+01 6.97893658e+01]
#  [5.03471140e+01 1.31705801e+00 6.97893658e+01]
#  [8.71790320e+00 2.59590618e+01 2.59590618e+01]]
# ```

# %%
# ваш код в этой ячейке

# %% [markdown]
# ## Задача 9. Работа с матрицами

# %% [markdown]
# Создайте двумерную матрицу `a` размером n*m.
#
# 1. Выведите транспонированную матрицу
# 2. Создайте матрицу `b`, размером n*m. Выведите на экран результат поэлементного вычитания матриц `a` и `b`.
# 3. Создайте матрицу `c` размером n*m. Выведите на экран результат поэлементного деления матриц `a` и `c`.

# %% [markdown]
# **Ввод**
#
# ```
# [[1 2 3]
#  [0 1 4]]
#
# [[2 3 1]
#  [0 1 2]]
#
# [[4 1 4]
#  [2 2 1]]
# ```
#
#
#
# **Вывод**
#
# ```
# [[1 0]
#  [2 1]
#  [3 4]]
#
# [[-1 -1  2]
#  [ 0  0  2]]
#
# [[0.25 2.   0.75]
#  [0.   0.5  4.  ]]
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 10. Истина или ложь

# %% [markdown]
# Дано два одномерных массива. Создайте массив, который получает поэлементно True, если сумма элементов первого и второго массива на соответствующей позиции является четным числом. В противной случае необходимо возвращать False.
#
# Необходимо реализовать задачу с помощью numpy.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# a = [7, 3, 5, 9, 2, 5, 4, 8, 9, 0]
# b = [2, 8, 6, 7, 1, 3, 2, 9, 5, 1]
#
# ```
#
# **Вывод:**
#
# ```
# [False, True, True, False, True, False, True, True, False, True]
# ```

# %%
# ваш код в этой ячейке
