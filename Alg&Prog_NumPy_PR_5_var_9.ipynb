# %% [markdown]
# # Введение в NumPy. Возможности библиотеки NumPy для работы с массивами. Массивы случайных чисел

# %% [markdown]
# # Вариант 9

# %% [markdown]
# ## Задача 1. Одномерный массив numpy

# %% [markdown]
# Создайте одномерный массив чисел от -7 до 4.
#
# Сделайте это двумя способами:

# %% [markdown]
# **Вывод**
#
# ```
# array([-7, -6, -5, -4, -3, -2, -1,  0,  1,  2,  3,  4])
# ```

# %% [markdown]
# - с помощью `arange`

# %%
# ваш код тут

# %% [markdown]
# - с помощью преобразования списка (list) в numpy `array`

# %%
# ваш код тут

# %% [markdown]
# ## Задача 2

# %% [markdown]
# Создайте массив numpy размером 6×6 со всеми значениями, равными `False`.
#
# *Подсказка:* создайте массив из нулей и приведите тип массива к `bool`.

# %% [markdown]
# **Вывод**
#
# ```
# array([[False, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False, False]])
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 3

# %% [markdown]
# Создайте массив 6×4, заполненный случайными целыми числами в интервале от 45 до 99.
# Выведите на экран:
#
# 1.   Массив
# 2.   Элемент на пересечении первой строки второго столбца
# 3.   Элемент на пересечении третьей строки четвёртого столбца
# 4.   Элемент на пересечении шестой строки первого столбца
# 5.   Первый элемент массива

# %% [markdown]
# **Вывод (случайный массив)**
#
# ```
# [[72 58 84 61]
#  [49 93 67 52]
#  [88 46 75 91]
#  [54 82 48 79]
#  [63 57 86 45]
#  [97 51 73 68]]
# 58
# 91
# 97
# 72
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 4

# %% [markdown]
# Вам дан массив под названием `test_array`. Выведите элементы этого массива, кратные 7.

# %%
test_array = np.array([21, -14, 15, 7, -10, 28, 9, -7, 35, 8])

# %% [markdown]
# **Вывод**
#
# ```
# array([ 21, -14,   7,  28,  -7,  35])
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 5

# %% [markdown]
# Вам дан массив `arr`. Выведите все его элементы, которые строго больше 1, и меньше или равны 8.
#
# *Подсказка:* здесь можно использовать булевы маски.

# %%
arr = np.array([0, 5, 15, 2, 8, -1, 9, 6, 7, 1])

# %% [markdown]
# **Вывод**
#
# ```
# array([5, 2, 8, 6, 7])
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 6. Замена элементов массива

# %% [markdown]
# Замените элементы из массива `test_array`, кратные 7, на `70`.
#
# *Подсказка:* вам пригодится функция `np.where`.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# test_array = np.array([21, -14, 15, 7, -10, 28, 9, -7, 35, 8])
# ```
#
# **Вывод:**
#
# ```
# array([70, 70, 15, 70, -10, 70,  9, 70, 70,  8])
# ```

# %%
# ваш код в этой ячейке

# %% [markdown]
# ## Задача 7. Случайная матрица

# %% [markdown]
# Программа принимает на вход четыре числа `n` - количество строк матрицы, `m` - количество столбцов матрицы, `a1` - начало интервала для заполнения матрицы случайными числами, `a2` - конец интервала для заполнения матрицы случайными числами.
#
# Создайте массив `n*m`, заполненный случайными целыми числами в интервале от `a1` до `a2`, и выведите его на экран.
# Подсчитайте и выведите на экран количество элементов массива, не превышающих значение середины интервала от `a1` до `a2`.

# %% [markdown]
# **Вывод (случайный массив)**
#
# ```
# [[35 62 48 71 54]
#  [59 41 77 52 68]
#  [56 45 64 50 73]]
# Количество элементов массива, не превышающих значение середины интервала от a1 до a2: 8
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 8. Применим функцию к массиву аргументов

# %% [markdown]
# y = 10·x² + 7·sin(x) + 6·exp(-x/12)

# %% [markdown]
# Запрограммируйте функцию с использованием возможностей numpy
#
# `y = 10*x**2 + 7*sin(x) + 6*exp(-x/12)`
#
# Создайте массив 4×4 и примените функцию сразу ко всем его аргументам.
# На экран вывести исходный массив и результат применения функции.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# [[2 1 3 0]
#  [4 2 1 3]
#  [0 3 2 4]
#  [1 0 4 2]]
# ```
#
# **Вывод:**
#
# ```
# [[2 1 3 0]
#  [4 2 1 3]
#  [0 3 2 4]
#  [1 0 4 2]]
# ---------------
# [[43.74704812 13.38247143 92.06019121  6.        ]
#  [162.34144069 43.74704812 13.38247143 92.06019121]
#  [ 6.         92.06019121 43.74704812 162.34144069]
#  [13.38247143  6.        162.34144069 43.74704812]]
# ```

# %%
# ваш код в этой ячейке

# %% [markdown]
# ## Задача 9. Работа с матрицами

# %% [markdown]
# Создайте двумерную матрицу `a` размером n×m.
#
# 1. Выведите транспонированную матрицу
# 2. Создайте матрицу `b`, размером m×k. Выведите на экран результат умножения матриц `a` и `b`.
# 3. Создайте матрицу `c` размером n×m. Выведите на экран результат умножения элементов матриц `a` и `c`.

# %% [markdown]
# **Ввод**
#
# ```
# [[5 3 2]
#  [1, 4, 6]]
#
# [[3 2]
#  [1, 4]
#  [2, 1]]
#
# [[2 1 3]
#  [3, 2, 1]]
# ```
#
#
#
# **Вывод**
#
# ```
# [[5 1]
#  [3 4]
#  [2 6]]
#
# [[22 24]
#  [19 42]]
#
# [[10  3  6]
#  [ 3  8  6]]
# ```

# %%
# ваш код тут

# %% [markdown]
# ## Задача 10. Истина или ложь

# %% [markdown]
# Дано два одномерных массива. Создайте массив, который получает поэлементно True, если чётные элементы первого массива строго больше соответствующего элемента второго, и True, если нечётные элементы второго массива больше или равны соответствующему элементу первого. В противном случае необходимо возвращать False.
#
# Необходимо реализовать задачу с помощью numpy.

# %% [markdown]
# ### Пример

# %% [markdown]
# **Ввод:**
#
# ```
# a = [6, 7, 4, 9, 2, 8, 3, 5, 1, 0]
# b = [4, 6, 3, 8, 5, 7, 2, 9, 4, 3]
#
# ```
#
# **Вывод:**
#
# ```
# [True, False, True, False, False, True, False, True, False, True]
# ```

# %%
# ваш код в этой ячейке
